# %% [markdown]
# Integrantes:
# - Angela Gonzalez
# - Juan Casanova
# - Juliana Filigrana

# %% [markdown]
# # Parte 1

# %% [markdown]
# ##  Análisis Exploratorio de Datos (EDA):

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns  
import statsmodels.api as sm
from sklearn.model_selection import train_test_split
from sklearn.impute import SimpleImputer

# %matplotlib inline

# %% [markdown]
# En este proyecto, se trabajaremos con el dataset **“HISTORICO_SUERTES.xlsx”**, que contiene información histórica de suertes, con variables de tipo numérico y categórico. El análisis EDA permitirá:
#
# - Revisar la estructura del dataset: número de registros y variables, tipos de datos, presencia de valores nulos.
#
# - Detectar problemas de calidad de los datos: como valores faltantes, duplicados o inconsistencias.
#
# - Analizar la distribución de las variables: para decidir la estrategia más adecuada de imputación y transformación.
#
# - Preparar los datos para análisis estadístico y modelado predictivo: garantizando que los resultados sean confiables y representativos.
#
# Esta primera fase es importante, ya que una comprensión adecuada de los datos evita errores en etapas posteriores, optimiza la selección de variables y asegura que los modelos de predicción tengan un desempeño óptimo.

# %% [markdown]
# **Carga y revisión inicial de los datos**
# Primero, cargamos el archivo “HISTORICO_SUERTES.xlsx” en nuestro entorno de trabajo usando pandas. Luego revisamos la estructura del dataset, obteniendo el número de filas y columnas, así como el tipo de cada variable.

# %%
#Loading our data
df = pd.read_excel('HISTORICO_SUERTES.xlsx')

# %%
#Numero de filas y columnas
df.shape
# Out:
# (21027, 85)

# %%
#Tipos de varibles
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21027 entries, 0 to 21026
# Data columns (total 85 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Período                    21027 non-null  int64
#  1   Hacienda                   21027 non-null  int64
#  2   Nombre                     21027 non-null  object
#  3   Zona                       21027 non-null  object
#  4   Tenencia                   21026 non-null  float64
#  5   Suerte                     21027 non-null  object
#  6   Suelo                      17269 non-null  object
#  7   Area Neta                  21027 non-null  float64
#  8   Dist Km                    21022 non-null  float64
#  9   Variedad                   21027 non-null  object
#  10  Cod.Estado #               21027 non-null  int64
#  11  Cod.Estado                 21027 non-null  object
#  12  F.Siembra                  21027 non-null  datetime64[ns]
# ...

# %%
#Cargar las primeras filas
df.head()
# Out:
#    Período  Hacienda             Nombre  Zona  Tenencia Suerte       Suelo  \
# 0   201701     80493          LA CONCHA  IP02      51.0   002A   CANTARINA
# 1   201701     81284    UKRANIA INCAUCA  IP05      81.0   039B         NaN
# 2   201701     80203      EL AMPARO SAA  IP05      31.0    007  CORINTIAS
# 3   201701     81380  SAN JUDAS INCAUCA  IP05      82.0   013A         NaN
# 4   201701     80298               JAVA  IP06      31.0   025A     GALPON
#
#    Area Neta  Dist Km   Variedad  ...  Humedad Rel Media Ciclo  \
# 0       6.00      4.3    CC85-92  ...                      NaN
# 1       1.45      NaN    CC85-92  ...                      NaN
# 2       8.24     23.0  CC01-1228  ...                      NaN
# 3       1.05     66.5  CC01-1940  ...                      NaN
# 4       4.53     17.0  RB73-2223  ...                      NaN
#
#   Oscilacion Temp Med 0-3 Oscilacion Temp Ciclo Sum Oscilacion Temp Ciclo  \
# ...

# %% [markdown]
# Esto nos permitió entender la estructura básica del dataset y el tipo de información que contiene, sentando la base para el siguiente paso: el análisis de valores faltantes y limpieza de datos.
#
# A continuación, realizamos un resumen estadístico de las columnas numéricas del dataset utilizando df.describe(). Esto nos permite obtener información importante sobre la distribución de los datos.

# %%
#Resumen estadistico
df.describe()
# Out:
#              Período      Hacienda      Tenencia     Area Neta       Dist Km  \
# count   21027.000000  21027.000000  21026.000000  21027.000000  21022.000000
# mean   202039.708708  80679.334427     46.448730      8.642948     25.311806
# min    201701.000000  80100.000000     11.000000      0.004000      1.100000
# 25%    201812.000000  80247.000000     31.000000      3.310000     12.000000
# 50%    202010.000000  80453.000000     51.000000      7.000000     21.900000
# 75%    202209.000000  81104.000000     51.000000     12.075000     32.700000
# max    202407.000000  82557.000000     91.000000     65.000000    155.000000
# std       216.642895    590.030150     21.513498      7.049533     18.237344
#
#        Cod.Estado #                      F.Siembra  \
# count  21027.000000                          21027
# mean       4.261806  2015-03-11 18:18:44.839492096
# min        0.000000            1986-04-30 00:00:00
# 25%        1.000000            2013-03-13 00:00:00
# ...

# %% [markdown]
# Este paso nos permitió tener una visión inicial de la magnitud, variabilidad y posibles inconsistencias de los datos numéricos, lo que servirá como base para la limpieza y preparación posterior, como la imputación de valores faltantes y detección de outliers.

# %%
# Visualizar la distribución de las variables de interés
plt.figure(figsize=(12, 6))

# Gráfico de la distribución de 'TCH'
plt.subplot(1, 2, 1)
sns.histplot(df['TCH'], kde=True, color='blue', bins=30)
plt.title('Distribución de TCH')

# Gráfico de la distribución de '%Sac.Caña'
plt.subplot(1, 2, 2)
sns.histplot(df['%Sac.Caña'], kde=True, color='green', bins=30)
plt.title('Distribución de %Sac.Caña')

plt.tight_layout()
plt.show()

# %% [markdown]
# **Variable TCH**
# - Es aproximadamente simétrica, lo que significa que la mayoría de los valores se concentran alrededor del centro.
# Sin embargo, se aprecia una ligera cola hacia la derecha (asimetría positiva). Esto indica que, aunque la mayor parte de los individuos tienen valores en torno al promedio, existen algunos casos con valores mucho más altos.
# - El pico del histograma está alrededor de los 130–150. Esto sugiere que la media y la mediana probablemente se ubican en ese rango, y que esa es la zona más representativa de la población analizada.

# %% [markdown]
# **Variable %Sac.Caña**
# - La distribución es muy simétrica y en forma de campana, lo que indica que sigue bastante bien una distribución normal. No se observan colas largas ni sesgos significativos: los datos están bien centrados.
#
# - Dado que la variable tiene una distribución normal clara y con baja dispersión, se trata de un indicador muy estable y homogéneo.
#
# - La mayor parte de los datos se concentran entre 11% y 13%, lo que sugiere una variabilidad baja.Existen algunos valores en los extremos (≈7% y ≈18%), pero son poco frecuentes y no distorsionan mucho la distribución.

# %%
# Identificación de outliers utilizando un gráfico de caja (boxplot)
plt.figure(figsize=(12, 6))

# Boxplot para 'TCH'
plt.subplot(1, 2, 1)
sns.boxplot(x=df['TCH'], color='blue')
plt.title('Boxplot de TCH')

# Boxplot para '%Sac.Caña'
plt.subplot(1, 2, 2)
sns.boxplot(x=df['%Sac.Caña'], color='green')
plt.title('Boxplot de %Sac.Caña')

plt.tight_layout()
plt.show()

# %% [markdown]
# TCH (Toneladas de caña por hectárea) tiene una alta variabilidad, con algunos valores atípicos que indican campos con rendimiento mucho mayor que el promedio. La distribución está sesgada hacia la derecha, con la mayoría de los valores bajos.
#
# %Sac.Caña (Porcentaje de sacarosa) tiene una distribución más equilibrada, concentrándose principalmente entre 9% y 13%, con algunos valores atípicos pero menos pronunciados que en TCH.

# %% [markdown]
# **Variable TCH**
#
# - Los bigotes se extienden desde ≈50 hasta ≈250, lo que significa que la mayoría de los datos caen en ese rango.
# - El boxplot muestra una distribución ligeramente sesgada a la derecha, porque hay más valores atípicos grandes que pequeños. Esto coincide con lo que ya vimos en el histograma: la variable TCH tiene una cola derecha más larga.
# - Aunque la mayoría de los datos de TCH se concentran en un rango estrecho (110–160), la presencia de tantos outliers altos y bajos indica una gran variabilidad.
# - Estos valores extremos pueden influir en la media y afectar análisis estadísticos sensibles a outliers.

# %% [markdown]
# **Variable %Sac.Caña**
# - Los bigotes se extienden desde ≈9% hasta ≈15–16%.
# - El boxplot es muy simétrico, confirmando que la variable sigue una distribución cercana a la normal. No hay sesgo evidente hacia ninguno de los lados.
# - El % de sacarosa en caña es un indicador más estable y homogéneo que TCH. Aunque existen valores atípicos, su número es reducido y no alteran la concentración central de los datos.

# %% [markdown]
# ### **Limpieza de datos**

# %% [markdown]
# Para asegurar que nuestro análisis sea confiable, realizamos un proceso de limpieza de datos, enfocado principalmente en los valores faltantes:
#
# - Copia del dataset original:
# Creamos df_clean como copia del dataset original para trabajar sin alterar los datos originales.
#
# - Detección de valores nulos:
# Identificamos el número de valores faltantes por columna con isnull().sum(). Esto nos permitió conocer qué variables podrían afectar el análisis si no se manejan adecuadamente.
#
# - Eliminación de columnas con exceso de nulos:
# Establecimos un umbral del 50%: cualquier columna con más del 50% de sus valores faltantes fue eliminada. Esto nos asegura mantener únicamente columnas con suficiente información para análisis confiables.

# %%
#Limpieza de datos 
df_clean = df.copy()

# %%
#Número de valores nulos por columna:
df_clean.isnull().sum()
# Out:
# Período                      0
# Hacienda                     0
# Nombre                       0
# Zona                         0
# Tenencia                     1
#                          ...
# Radiacion Solar Ciclo    16497
# Precipitacion 0_3        16497
# Precipitacion Ciclo      16497
# Evaporacion 0-3          16497
# Evaporacion Ciclo        16497
# Length: 85, dtype: int64

# %%
# --- 1. Eliminar columnas con más del 50% de valores nulos ---
nulos = df.isnull().sum()
umbral = 0.5 * len(df)
df_clean2 = df.loc[:, nulos < umbral].copy()  # .copy() evita SettingWithCopyWarning

print("Columnas eliminadas por exceso de nulos:", df.columns[~df.columns.isin(df_clean2.columns)])
print("Número de columnas restantes:", df_clean2.shape[1])
# Out:
# Columnas eliminadas por exceso de nulos: Index(['D.S.', 'Ult.Riego', 'Edad.Precosecha', 'Num.Riegos', '%Infest.Diatrea',
#        'Fert.Nitrogen.', 'Urea 46%', 'MEZ', 'Boro Granul.', 'MicroZinc',
#        'NITO_XTEND', 'Sul.Amonio', 'NITRAX-S', 'Vinaza', 'Codigo Estacion',
#        'Temp. Media 0-3', 'Temp. Media Ciclo', 'Temp Max Ciclo',
#        'Temp Min Ciclo', 'Humedad Rel Media 0-3 ', 'Humedad Rel Media Ciclo',
#        'Oscilacion Temp Med 0-3', 'Oscilacion Temp Ciclo',
#        'Sum Oscilacion Temp Ciclo', 'Radicion Solar 0-3',
#        'Radiacion Solar Ciclo', 'Precipitacion 0_3', 'Precipitacion Ciclo',
#        'Evaporacion 0-3', 'Evaporacion Ciclo'],
#       dtype='object')
# Número de columnas restantes: 55

# %% [markdown]
# **Imputación de valores nulos**
#
# Después de eliminar columnas con más del 50% de nulos, completamos los faltantes según el tipo de variable:
#
# - Numéricas: según su asimetría, usamos media (simétricas) o mediana (sesgadas). Calculamos la asimetría (skewness) de cada columna numérica para determinar su distribución.
#
# **Regla usada:**
#
# Distribución aproximadamente simétrica (-0.5 <= skew <= 0.5) → imputamos con la media.
#
# Distribución sesgada → imputamos con la mediana.
#
# Esto asegura que la imputación no distorsione la distribución original de los datos.
#
# - Categóricas: Se imputaron los valores faltantes con la moda (valor más frecuente). Esto mantiene la coherencia de las categorías sin alterar significativamente la distribución.
#
# - Fechas: Se completaron los valores faltantes usando la fecha más frecuente (moda). Esto permite conservar información temporal importante para el análisis sin perder registros.
#
# Finalmente, verificamos que ya no quedaran valores nulos, dejando el dataset listo para análisis.

# %%
# --- 2. Imputación según skewness para columnas numéricas ---
numeric_cols = df_clean2.select_dtypes(include=['int64','float64']).columns
skew_values = df_clean2[numeric_cols].skew()

for col in numeric_cols:
    if -0.5 <= skew_values[col] <= 0.5:
        # Distribución aproximadamente simétrica → usar media
        imputer = SimpleImputer(strategy='mean')
    else:
        # Distribución sesgada → usar mediana
        imputer = SimpleImputer(strategy='median')
    
    df_clean2.loc[:, col] = imputer.fit_transform(df_clean2[[col]])

# --- 3. Imputación para columnas categóricas ---
categorical_cols = df_clean2.select_dtypes(include=['object']).columns
imputer_cat = SimpleImputer(strategy='most_frequent')
df_clean2.loc[:, categorical_cols] = imputer_cat.fit_transform(df_clean2[categorical_cols])

# --- 4. Imputación para columnas de fechas ---
date_cols = df_clean2.select_dtypes(include=['datetime64[ns]']).columns
for col in date_cols:
    # Usamos la fecha más frecuente (moda)
    moda_fecha = df_clean2[col].mode()[0]
    df_clean2.loc[:, col] = df_clean2[col].fillna(moda_fecha)

# --- 5. Verificar que ya no hay nulos ---
print(df_clean2.isnull().sum())
# Out:
# Período                   0
# Hacienda                  0
# Nombre                    0
# Zona                      0
# Tenencia                  0
# Suerte                    0
# Suelo                     0
# Area Neta                 0
# Dist Km                   0
# Variedad                  0
# Cod.Estado #              0
# Cod.Estado                0
# F.Siembra                 0
# Edad Ult Cos              0
# F.Ult.Corte               0
# Destino 1=Semilla         0
# Cod. T.Cultivo            0
# Cultivo                   0
# Fec.Madur.                0
# Producto                  0
# Dosis Madurante           0
# Semanas mad.              0
# TonUltCorte               0
# TCH                       0
# TCHM                      0
# Ton.Azucar                0
# Rdto                      0
# TAH                       0
# TAHM                      0
# Sac.Caña Precosecha       0
# %Sac.Caña                 0
# %Sac.Muestreadora         0
# %ATR                      0
# ...

# %% [markdown]
# Con esta imputación, nuestro dataset df_clean2 queda completo y listo para análisis exploratorio y modelado, manteniendo la integridad y representatividad de los datos según su tipo y distribución.

# %% [markdown]
# ##  **Desarrollo de Modelos:**

# %% [markdown]
# ### **Preparación de variables para modelos de regresión**

# %% [markdown]
# En esta etapa, haremos el análisis necesario para seleccionar las variables más relevantes que alimentarán nuestros modelos de regresión lineal sobre TCH y %Sac.Caña. El objetivo es identificar cuáles variables numéricas tienen una relación fuerte con nuestros objetivos de predicción, de manera que los modelos sean más precisos y confiables.
#
# 1. Correlación de variables numéricas: Seleccionamos solo las columnas numéricas del dataset limpio.
# 2. Filtrado por umbral: Definimos un umbral de correlación de ±0.7 para considerar variables relevantes.
# 3. Visualización: Generamos heatmaps para ver la relación entre las variables más importantes y confirmar visualmente su fuerza de correlación.

# %%
# Seleccionar solo las columnas numéricas
numeric_columns = df_clean2.select_dtypes(include=['float64', 'int64']).columns

# Correlación entre las variables numéricas y TCH, %Sac.Caña
correlation_matrix = df_clean2[numeric_columns].corr()

print(correlation_matrix[['TCH', '%Sac.Caña']])

# Visualización de la matriz de correlación
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix[['TCH', '%Sac.Caña']], annot=True, cmap='coolwarm', fmt='.2f', linewidths=0.5)
plt.title('Correlación con TCH y %Sac.Caña')
plt.show()
# Out:
#                              TCH  %Sac.Caña
# Período                -0.122134  -0.119150
# Hacienda               -0.051714   0.050330
# Tenencia               -0.021053   0.037325
# Area Neta               0.093021   0.112105
# Dist Km                -0.048454   0.047547
# Cod.Estado #           -0.225865   0.097505
# Edad Ult Cos            0.298166   0.057568
# Destino 1=Semilla      -0.119599  -0.000404
# Cod. T.Cultivo          0.003552  -0.269296
# Dosis Madurante        -0.015001   0.284191
# Semanas mad.            0.013928   0.067819
# TonUltCorte             0.320696   0.049118
# TCH                     1.000000  -0.164438
# TCHM                    0.829980  -0.214033
# Ton.Azucar              0.293135   0.139904
# Rdto                   -0.051381   0.724352
# TAH                     0.856234   0.206277
# TAHM                    0.729492   0.179770
# Sac.Caña Precosecha     0.071535   0.218483
# %Sac.Caña              -0.164438   1.000000
# ...

# %%
# Definir un umbral de correlación para considerar variables importantes (por ejemplo, 0.7 o -0.7)
threshold = 0.7

# Filtrar las variables más correlacionadas con TCH y %Sac.Caña
correlated_tch = correlation_matrix['TCH'][abs(correlation_matrix['TCH']) > threshold].index.tolist()
correlated_sac = correlation_matrix['%Sac.Caña'][abs(correlation_matrix['%Sac.Caña']) > threshold].index.tolist()

# Mostrar las variables más correlacionadas con TCH y %Sac.Caña
print("Variables más correlacionadas con TCH:", correlated_tch)
print("Variables más correlacionadas con %Sac.Caña:", correlated_sac)

plt.figure(figsize=(12, 8))

# Visualizar las variables más correlacionadas con TCH y %Sac.Caña
sns.heatmap(correlation_matrix.loc[correlated_tch + correlated_sac, correlated_tch + correlated_sac], annot=True, cmap='coolwarm', fmt='.2f', linewidths=0.8, linecolor='white', cbar_kws={'shrink': 0.8})

plt.title('Matriz de Correlación: Variables Más Correlacionadas con TCH y %Sac.Caña', fontsize=16, weight='bold')
plt.xticks(rotation=45, ha='right', fontsize=12)
plt.yticks(rotation=0, fontsize=12)
plt.tight_layout()
plt.show()
# Out:
# Variables más correlacionadas con TCH: ['TCH', 'TCHM', 'TAH', 'TAHM', 'KATRHM']
# Variables más correlacionadas con %Sac.Caña: ['Rdto', '%Sac.Caña', '%ATR']

# %% [markdown]
# ### **TCH -> Modelo**

# %% [markdown]
# Variables más correlacionadas con **TCH**:  **[**'TCH', 'TCHM', 'TAH', 'TAHM', 'KATRHM' **]**
#
#
# **Analisis para escoger variables**
#
# - Al analizar la correlación entre las variables:
#
# 1. **TCH y TCHM → Son iguales**.
#
# Esto significa que TCHM no aporta información nueva, por lo que no la incluimos en el análisis.
#
# 2. **TAH y TAHM → Son iguales**.
#
# Para evitar duplicidad, solo usaremos TAH.
#
# 3. **KATRHM**
#
# Es un indicador compatible con TCH y aporta información relevante sobre rendimiento.

# %% [markdown]
# Ahora analizaremos la relacion entre estas que escogimos:

# %%
X = df_clean2[['TAH', 'KATRHM']]
X.corr()
# Out:
#              TAH    KATRHM
# TAH     1.000000  0.740499
# KATRHM  0.740499  1.000000

# %% [markdown]
# TAH y KATRHM aportan información similar al modelo para explicar TCH. pero principalmente TAH es la variable más relevante.
#
# KATRHM: aunque aporta información sobre rendimiento, es un índice derivado estrechamente relacionado con TCH, lo que podría generar multicolinealidad. Por esto también fue eliminada.

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score


# Variables predictoras (X) y variable objetivo (y)
X = df_clean2[['TAH']]
y = df_clean2['TCH']

X_train, X_test, y_train, y_test = train_test_split(
    X, 
    y, 
    test_size=0.3, 
    random_state=42
)

# Agregar término de sesgo para regresión lineal
X_train_1 = sm.add_constant(X_train)
# Ajustar modelo de regresión lineal con statsmodels
lin_model = sm.OLS(y_train, X_train_1).fit()
lin_model.params
# Out:
# const    27.298204
# TAH       7.368618
# dtype: float64

# %% [markdown]
# Por cada unidad de cambio en TAH, que en este caso es 1 hectárea adicional plantada, se espera que el rendimiento TCH aumente en 7.37 toneladas de caña.

# %%
lin_model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                    TCH   R-squared:                       0.725
# Model:                            OLS   Adj. R-squared:                  0.725
# Method:                 Least Squares   F-statistic:                 3.884e+04
# Date:                Fri, 05 Sep 2025   Prob (F-statistic):               0.00
# Time:                        15:38:23   Log-Likelihood:                -62728.
# No. Observations:               14718   AIC:                         1.255e+05
# Df Residuals:                   14716   BIC:                         1.255e+05
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         27.2982      0.540     50.564      0.000      26.240      28.356
# ...

# %% [markdown]
# El R² = 0.725 indica que el 72.5% de la variabilidad en TCH es explicada por TAH.
#
# La prueba F tiene un p-valor ≈ 0, confirmando que el modelo es estadísticamente significativo en su conjunto.

# %% [markdown]
# ### **Supuestos del modelo TCH**

# %% [markdown]
# #### **Verificación de la Linealidad**

# %%
# --- Residuos y valores ajustados ---
residuals = lin_model.resid
fitted = lin_model.fittedvalues

# 1. Verificación de la Linealidad
plt.figure(figsize=(5, 5))
sns.residplot(x=fitted, y=residuals)
plt.xlabel('Valores Ajustados')
plt.ylabel('Residuos')
plt.title('Residuos vs Valores Ajustados')
plt.show()

# %% [markdown]
# - El gráfico muestra que los residuos se distribuyen alrededor de 0 sin un patrón sistemático claro.
#
# - Eso significa que la relación entre las variables independientes y la variable dependiente puede considerarse lineal.
#
# - Aunque existen algunos outliers extremos, no se observa una tendencia curva ni pendiente marcada que rompa la linealidad.

# %% [markdown]
# #### **Verificación de la Independencia de los Errores**

# %%
from statsmodels.stats.stattools import durbin_watson

# 2. Verificación de la Independencia de los Errores
dw_stat = durbin_watson(residuals)
print(f'Estadístico de Durbin-Watson: {dw_stat:.2f}')
# Out:
# Estadístico de Durbin-Watson: 2.01

# %% [markdown]
# Se evaluó la independencia de los errores mediante el estadístico de Durbin-Watson. Con un valor de 2.01, los residuos del modelo no presentan autocorrelación significativa, cumpliendo el supuesto de independencia.

# %% [markdown]
# #### **Verificación de la Homoscedasticidad**

# %%
# Verificación de Homoscedasticidad (varianza constante) correctamente
from statsmodels.stats.diagnostic import het_breuschpagan

X_train_const = sm.add_constant(X_train)  # X_train usado en el modelo

bp_test = het_breuschpagan(residuals, X_train_const)
labels = ['LM Statistic', 'LM-Test p-value', 'F-Statistic', 'F-Test p-value']
print(dict(zip(labels, bp_test)))
# Out:
# {'LM Statistic': np.float64(24.410859291226444), 'LM-Test p-value': np.float64(7.782874993699904e-07), 'F-Statistic': np.float64(24.448091061321104), 'F-Test p-value': np.float64(7.718039685104318e-07)}

# %% [markdown]
# La prueba de Breusch-Pagan indica que la varianza de los errores no es constante (p < 0.05), por lo que el supuesto de homoscedasticidad no se cumple. Esto sugiere que los errores estándar de los coeficientes podrían no ser confiables, afectando la validez de los intervalos de confianza y los p-values

# %% [markdown]
# #### **Verificación de la Normalidad de los Errores**

# %%
# !pip install pingouin

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import statsmodels.api as sm
import pingouin as pg

# %%
# Semilla para reproducibilidad
np.random.seed(42)

# %%
# -------------------------------
# 1️ Comparación con distribuciones no normales
n = 1000
uniform_data = np.random.uniform(low=0, high=10, size=n)
exponential_data = np.random.exponential(scale=2, size=n)
gamma_data = np.random.gamma(shape=2, scale=2, size=n)
chi_square_data = np.random.chisquare(df=4, size=n)
beta_data = np.random.beta(a=2, b=5, size=n)
weibull_data = np.random.weibull(a=1.5, size=n) * 2

distributions = [
    ("Uniforme", uniform_data),
    ("Exponencial", exponential_data),
    ("Gamma", gamma_data),
    ("Chi-cuadrado", chi_square_data),
    ("Beta", beta_data),
    ("Weibull", weibull_data),
]

plt.figure(figsize=(12, 8))
for i, (name, values) in enumerate(distributions, start=1):
    plt.subplot(2, 3, i)
    sns.histplot(values, kde=True, bins=30, color="skyblue", edgecolor="black")
    plt.title(name)
    plt.xlabel("Valores")
    plt.ylabel("Frecuencia")
plt.tight_layout()
plt.show()

# Q-Q plots de las distribuciones no normales
plt.figure(figsize=(12, 8))
for i, (name, values) in enumerate(distributions, start=1):
    plt.subplot(2, 3, i)
    pg.qqplot(values)
    plt.title(name)
plt.tight_layout()
plt.show()

# %%
# -------------------------------
# 2️ Comparación con distribución normal
data_normal = np.random.normal(loc=0, scale=1, size=n)

plt.figure(figsize=(10,7))
plt.subplot(121)
sns.histplot(data_normal, kde=True, bins=30, color="skyblue", edgecolor="black")
plt.title("Distribución Normal")
plt.subplot(122)
pg.qqplot(data_normal)
plt.title("Q-Q Normal")
plt.tight_layout()
plt.show()

# %%
# -------------------------------
# 3️Verificación de normalidad de los residuos del modelo
plt.figure(figsize=(6,6))
sm.qqplot(residuals, line='45', fit=True)
plt.title('Q-Q Plot de los Residuos')
plt.show()

# Histograma de los residuos
plt.figure(figsize=(6,4))
sns.histplot(residuals, kde=True, color="salmon", edgecolor="black", bins=30)
plt.title('Histograma de Residuos')
plt.xlabel('Residuos')
plt.ylabel('Frecuencia')
plt.show()

# %% [markdown]
# ### **%Sac.Caña -> Modelo**

# %% [markdown]
# Variables más correlacionadas con **%Sac.Caña**: **[**'Rdto', '%Sac.Caña', '%ATR'**]**
#
# **Análisis para escoger variables**
#
# Rdto → Rendimiento general del cultivo.
#
# Esta variable muestra correlación positiva con %Sac.Caña y aporta información útil sobre la cantidad producida. Se incluye en el modelo como predictor.
#
# %ATR → Porcentaje de azúcares totales recuperables.
#
# %ATR tiene una relación directa con la calidad de la caña y complementa la información de Rdto. También se incluye como predictor en el modelo.

# %% [markdown]
# Ahora analizaremos la relacion entre estas que escogimos:

# %%
X = df_clean2[['Rdto', '%ATR']]
X.corr()
# Out:
#           Rdto      %ATR
# Rdto  1.000000  0.549711
# %ATR  0.549711  1.000000

# %% [markdown]
# Ninguna de las variables está perfectamente correlacionada (correlación < 0.9), por lo que ambas aportan información relevante y complementaria al análisis.
#
# Esto justifica incluir tanto Rdto como %ATR como variables predictoras o explicativas en un modelo, ya que ninguna duplica completamente la información de la otra.
#
# Correlación entre las variables: 0.55 → moderada, no demasiado alta.
#
# Ninguna variable es un derivado exacto de la otra → ambas aportan información relevante.

# %%
# Variables predictoras (X) y variable objetivo (y)
X = df_clean2[['Rdto', '%ATR']]  # Ahora incluimos las dos variables
y = df_clean2['%Sac.Caña']       # Variable objetivo

# Dividir en conjunto de entrenamiento y prueba
X_train, X_test, y_train, y_test = train_test_split(
    X, 
    y, 
    test_size=0.3, 
    random_state=42
)

# Agregar término de sesgo para statsmodels
X_train_1 = sm.add_constant(X_train)

# Ajustar modelo de regresión lineal con statsmodels
lin_model = sm.OLS(y_train, X_train_1).fit()

# Mostrar los coeficientes del modelo
print(lin_model.params)
# Out:
# const    3.790766
# Rdto     0.380545
# %ATR     0.323895
# dtype: float64
